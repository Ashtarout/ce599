# %% [markdown]
# # Mapping
#
# Transportation is about getting from place A to place B.  Therefore, most transportation data has a spatial component to it.  It is nice to be able to put these data on a map and see what is going on.  It is even better if we can put it on a map and interact with the data.  It would be even cooler if we could put our interactive map on a website to show it off!
#
# To do this, we are going to use a package called folium.  You can find the documentation here:
#
# https://folium.readthedocs.io/en/latest/
#
# And access it on github here:
#
# https://github.com/python-visualization/folium

# %% [markdown]
# ### Credits
#
# This lesson draws from the folium quickstart notebook, and from Vik Paruchuri DataQuest lesson:
#
# https://www.dataquest.io/blog/python-data-visualization-libraries/

# %% [markdown]
# ### A side note on static mapping
#
# Sometimes you may want to create a static map instead of an interactive map.  Interactive maps are nice for exploring your data, but static maps work well for an image that you can insert into a paper.  If you want to create static maps, then basemap is a good tool.  Here is a nice lesson focused on mapping earthquake activity:
#
# http://introtopython.org/visualization_earthquakes.html

# %% [markdown]
# ### OK, back to interactive mapping, because that's fun...
#
# It turns out that folium doesn't do much itself.  It is just a wrapper around something called leafletjs.  You can read more about that here:
#
# http://leafletjs.com/index.html
#
# Leaflet is a library in the JavaScript language.  JavaScript is the language used for most web applications.  We could do the same thing using JavaScript and leaflet directly, but then we would have to learn the syntax for another language.  That might not be too hard, but to keep it simple, we'll stick to the python wrapper for now.  It is good to be aware of, though, because if you want more options than folium allows, you can go directly to leaflet.
#
# What makes this possible is the fact that leaflet has a well-defined API.  That means that we can pass data back and forth, even from a different language.

# %% [markdown]
# ### Setup
#
# Start by installing folium using pip.  At a command prompt, type:
#
#     pip install folium
#
# Hmm...when I tried this on my desktop, I get an error that says:
#
#     PermissionError: [WinError 5] Access is denied: 'c:\\program files\\anaconda3\\Lib\\site-packages\\folium'
#
# It seems that it is trying to install something in the program files directory, which Windows has protected.  This will depend on the security settings on your machine.  If you get this error, open a command prompt as an administrator.  In the windows search bar, type cmd.  When you see the command prompt, right click, and select run as administrator.
#
# This did the trick, and now I get:
#
#     Successfully installed folium-0.2.1
#
# In addition, let's go to github and clone the folium repository (https://github.com/python-visualization/folium) to our desktop.  This gives us the source code on our local machine.  What we're really interested in is the examples folder, which gives us a bunch of jupyter notebooks showing how to do different stuff.  You are welcome to explore these as needed.
#
# You also need to install geopandas, which will make it easier to work with goegraphic data.  The pip installer doesn't work (the long explanation is here: http://geoffboeing.com/2014/09/using-geopandas-windows/), so we'll install using anaconda.  Type:
#
#     conda install -c conda-forge geopandas

# %% [markdown]
# Getting Started
# ---------------
#
# To create a base map, simply pass your starting coordinates to Folium:

# %%
import folium

# %%
m = folium.Map(location=[38.034,-84.500])

# %% [markdown]
# to display it in your notebook, just ask for the object representation.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c2d074067afd48b5a584661a846b7c2f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c2d074067afd48b5a584661a846b7c2f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c2d074067afd48b5a584661a846b7c2f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c2d074067afd48b5a584661a846b7c2f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# To save it in a file

# %%
m.save('lex.html')

# %% [markdown]
# We can use different backgrounds, or tilesets.  Several are built in.  Options include Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control room tiles.

# %%
folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1ab582e4509643d3be3e8253b694d9c1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1ab582e4509643d3be3e8253b694d9c1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1ab582e4509643d3be3e8253b694d9c1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1ab582e4509643d3be3e8253b694d9c1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Pick one you like and work with that for the rest of the class.

# %% [markdown]
# Folium also supports Cloudmade and Mapbox custom tilesets- simply pass your key to the API_key keyword.  These are services where you can buy more backgrounds to make your maps look nice.
#
# ```python
# folium.Map(location=[45.5236, -122.6750],
#            tiles='Mapbox',
#            API_key='your.API.key')
# ```

# %% [markdown]
# ### Open flights
#
# Let's go back to our openflight data and make some maps.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
# let's peek at what we have
airports.head()
# Out:
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airlines.head()
# Out:
#    id                                          name alias iata icao callsign  \
# 0  -1                                       Unknown   NaN    -  NaN      NaN
# 1   1                                Private flight   NaN    -  NaN      NaN
# 2   2                                   135 Airways   NaN  NaN  GNL  GENERAL
# 3   3                                 1Time Airline   NaN   1T  RNX  NEXTIME
# 4   4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT      NaN
#
#           country active
# 0             NaN      Y
# 1             NaN      Y
# 2   United States      N
# 3    South Africa      Y
# 4  United Kingdom      N

# %%
routes.head()
# Out:
#   airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3      2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4      2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# Make a map with the airports on it.

# %%
# since there are a lot of airports, making the map can be slow
# so limit it to US airports
us_airports = airports[airports['country']=='United States']
len(us_airports)
# Out:
# 1435

# %%
# Get a basic world map.
# 30 centers the map E-W, and 0 is the equator
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# Loop through the airports, and draw each one as a marker on the map
# popup tells it what to display when you click on it
for name, row in us_airports.iterrows():
    
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.Marker([row["latitude"], row["longitude"]], popup=row['name'])
        marker.add_to(airports_map)
        
# Save it to a file (it's kinda big for the notebook)
airports_map.save('airports.html')

# %%
airports_map.save('airports.html')

# %% [markdown]
# Hmm...it looks like there are airports everywhere!  Let's try again with smaller makers.
#
# We can also specify the color.  A list of custom colors is available here:
#
# http://www.w3schools.com/cssref/css_colors.asp

# %%
# over-write the airports_map, rather than just adding more markers to it. 
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# use circle markers this time, with custom size and color
for name, row in us_airports.iterrows():
        
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.CircleMarker([row["latitude"], row["longitude"]], 
                                     radius=5,
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     popup=row['name'])
        marker.add_to(airports_map)
        
airports_map.save('airports.html')

# %% [markdown]
# You can also select icons to use as markers.  That code would look like:
#
#     marker = folium.Marker([row["latitude"], row["longitude"]],
#                            icon=folium.Icon(icon='cloud'),
#                            popup=row['name'])
#
# The list of icons comes from something called bootstrap, and can be found here:
#
# http://www.bootstrapicons.com/

# %% [markdown]
# Or you can use clusters of markers to clean up the map.  This will group them when you zoom out, similar to a Craigslist map.  You can see how to do that here:
#
# https://ocefpaf.github.io/python4oceanographers/blog/2015/12/14/geopandas_folium/
#
# You can clean up the rest of this airports map as part of your homework this week.

# %% [markdown]
# Let's draw the routes, but since we have lots, let's just start with the routes departing Lexington.

# %%
# Select the LEX routes, then join the source airports
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')
lex_routes
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment    id  ... iata  icao   latitude  longitude altitude  \
# 0           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 1       CR7 CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 2       ERD ER4  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 3       ERD ER4  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 4       CRJ CR9  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 5       M88 717  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 6           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 7   CR7 CRJ CR9  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 8           ERJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 9           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 10          M80  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 11          M80  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 12          320  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 13      M80 320  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 14      CR9 CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 15          ERJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 16      ERJ CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 17          CR7  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 18          ERD  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 19      ERD ER4  4017  ...  LEX  KLEX  38.036499 -84.605904      979
#
#     timezone  dst                tz     type     source_y
# 0       -5.0    A  America/New_York  airport  OurAirports
# 1       -5.0    A  America/New_York  airport  OurAirports
# 2       -5.0    A  America/New_York  airport  OurAirports
# 3       -5.0    A  America/New_York  airport  OurAirports
# 4       -5.0    A  America/New_York  airport  OurAirports
# 5       -5.0    A  America/New_York  airport  OurAirports
# 6       -5.0    A  America/New_York  airport  OurAirports
# 7       -5.0    A  America/New_York  airport  OurAirports
# 8       -5.0    A  America/New_York  airport  OurAirports
# 9       -5.0    A  America/New_York  airport  OurAirports
# 10      -5.0    A  America/New_York  airport  OurAirports
# 11      -5.0    A  America/New_York  airport  OurAirports
# 12      -5.0    A  America/New_York  airport  OurAirports
# 13      -5.0    A  America/New_York  airport  OurAirports
# 14      -5.0    A  America/New_York  airport  OurAirports
# 15      -5.0    A  America/New_York  airport  OurAirports
# 16      -5.0    A  America/New_York  airport  OurAirports
# 17      -5.0    A  America/New_York  airport  OurAirports
# 18      -5.0    A  America/New_York  airport  OurAirports
# 19      -5.0    A  America/New_York  airport  OurAirports
#
# [20 rows x 23 columns]

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])

# %%
# here is what our data looks like
lex_routes
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment  id_source  ... iata_dest icao_dest latitude_dest  \
# 0           CRJ       4017  ...       ATL      KATL     33.636700
# 1       CR7 CRJ       4017  ...       CLT      KCLT     35.214001
# 2       ERD ER4       4017  ...       DFW      KDFW     32.896801
# 3       ERD ER4       4017  ...       ORD      KORD     41.978600
# 4       CRJ CR9       4017  ...       ATL      KATL     33.636700
# 5       M88 717       4017  ...       ATL      KATL     33.636700
# 6           CRJ       4017  ...       DCA      KDCA     38.852100
# 7   CR7 CRJ CR9       4017  ...       DTW      KDTW     42.212399
# 8           ERJ       4017  ...       LGA      KLGA     40.777199
# 9           CRJ       4017  ...       MSP      KMSP     44.882000
# 10          M80       4017  ...       FLL      KFLL     26.072599
# 11          M80       4017  ...       PGD      KPGD     26.920200
# 12          320       4017  ...       PIE      KPIE     27.910200
# 13      M80 320       4017  ...       SFB      KSFB     28.777599
# 14      CR9 CRJ       4017  ...       ATL      KATL     33.636700
# 15          ERJ       4017  ...       IAH      KIAH     29.984400
# 16      ERJ CRJ       4017  ...       ORD      KORD     41.978600
# 17          CR7       4017  ...       CLT      KCLT     35.214001
# 18          ERD       4017  ...       DFW      KDFW     32.896801
# 19      ERD ER4       4017  ...       ORD      KORD     41.978600
#
#    longitude_dest altitude_dest  timezone_dest  dst_dest           tz_dest  \
# 0      -84.428101          1026           -5.0         A  America/New_York
# 1      -80.943100           748           -5.0         A  America/New_York
# 2      -97.038002           607           -6.0         A   America/Chicago
# 3      -87.904800           672           -6.0         A   America/Chicago
# 4      -84.428101          1026           -5.0         A  America/New_York
# 5      -84.428101          1026           -5.0         A  America/New_York
# 6      -77.037697            15           -5.0         A  America/New_York
# 7      -83.353401           645           -5.0         A  America/New_York
# 8      -73.872597            21           -5.0         A  America/New_York
# 9      -93.221802           841           -6.0         A   America/Chicago
# 10     -80.152702             9           -5.0         A  America/New_York
# 11     -81.990501            26           -5.0         A  America/New_York
# 12     -82.687401            11           -5.0         A  America/New_York
# 13     -81.237503            55           -5.0         A  America/New_York
# 14     -84.428101          1026           -5.0         A  America/New_York
# 15     -95.341400            97           -6.0         A   America/Chicago
# 16     -87.904800           672           -6.0         A   America/Chicago
# 17     -80.943100           748           -5.0         A  America/New_York
# 18     -97.038002           607           -6.0         A   America/Chicago
# 19     -87.904800           672           -6.0         A   America/Chicago
#
#     type_dest       source
# 0     airport  OurAirports
# 1     airport  OurAirports
# 2     airport  OurAirports
# 3     airport  OurAirports
# 4     airport  OurAirports
# 5     airport  OurAirports
# 6     airport  OurAirports
# 7     airport  OurAirports
# 8     airport  OurAirports
# 9     airport  OurAirports
# 10    airport  OurAirports
# 11    airport  OurAirports
# 12    airport  OurAirports
# 13    airport  OurAirports
# 14    airport  OurAirports
# 15    airport  OurAirports
# 16    airport  OurAirports
# 17    airport  OurAirports
# 18    airport  OurAirports
# 19    airport  OurAirports
#
# [20 rows x 37 columns]

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
lex_routes = lex_routes.drop(['source_y','source'], axis=1)
lex_routes = lex_routes.rename(columns={'source_x': 'source'})
lex_routes
# Out:
#    airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0    LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0    LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0    LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0    LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment  id_source  ...   country_dest iata_dest icao_dest  \
# 0           CRJ       4017  ...  United States       ATL      KATL
# 1       CR7 CRJ       4017  ...  United States       CLT      KCLT
# 2       ERD ER4       4017  ...  United States       DFW      KDFW
# 3       ERD ER4       4017  ...  United States       ORD      KORD
# 4       CRJ CR9       4017  ...  United States       ATL      KATL
# 5       M88 717       4017  ...  United States       ATL      KATL
# 6           CRJ       4017  ...  United States       DCA      KDCA
# 7   CR7 CRJ CR9       4017  ...  United States       DTW      KDTW
# 8           ERJ       4017  ...  United States       LGA      KLGA
# 9           CRJ       4017  ...  United States       MSP      KMSP
# 10          M80       4017  ...  United States       FLL      KFLL
# 11          M80       4017  ...  United States       PGD      KPGD
# 12          320       4017  ...  United States       PIE      KPIE
# 13      M80 320       4017  ...  United States       SFB      KSFB
# 14      CR9 CRJ       4017  ...  United States       ATL      KATL
# 15          ERJ       4017  ...  United States       IAH      KIAH
# 16      ERJ CRJ       4017  ...  United States       ORD      KORD
# 17          CR7       4017  ...  United States       CLT      KCLT
# 18          ERD       4017  ...  United States       DFW      KDFW
# 19      ERD ER4       4017  ...  United States       ORD      KORD
#
#    latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0      33.636700     -84.428101           1026           -5.0         A
# 1      35.214001     -80.943100            748           -5.0         A
# 2      32.896801     -97.038002            607           -6.0         A
# 3      41.978600     -87.904800            672           -6.0         A
# 4      33.636700     -84.428101           1026           -5.0         A
# 5      33.636700     -84.428101           1026           -5.0         A
# 6      38.852100     -77.037697             15           -5.0         A
# 7      42.212399     -83.353401            645           -5.0         A
# 8      40.777199     -73.872597             21           -5.0         A
# 9      44.882000     -93.221802            841           -6.0         A
# 10     26.072599     -80.152702              9           -5.0         A
# 11     26.920200     -81.990501             26           -5.0         A
# 12     27.910200     -82.687401             11           -5.0         A
# 13     28.777599     -81.237503             55           -5.0         A
# 14     33.636700     -84.428101           1026           -5.0         A
# 15     29.984400     -95.341400             97           -6.0         A
# 16     41.978600     -87.904800            672           -6.0         A
# 17     35.214001     -80.943100            748           -5.0         A
# 18     32.896801     -97.038002            607           -6.0         A
# 19     41.978600     -87.904800            672           -6.0         A
#
#              tz_dest type_dest
# 0   America/New_York   airport
# 1   America/New_York   airport
# 2    America/Chicago   airport
# 3    America/Chicago   airport
# 4   America/New_York   airport
# 5   America/New_York   airport
# 6   America/New_York   airport
# 7   America/New_York   airport
# 8   America/New_York   airport
# 9    America/Chicago   airport
# 10  America/New_York   airport
# 11  America/New_York   airport
# 12  America/New_York   airport
# 13  America/New_York   airport
# 14  America/New_York   airport
# 15   America/Chicago   airport
# 16   America/Chicago   airport
# 17  America/New_York   airport
# 18   America/Chicago   airport
# 19   America/Chicago   airport
#
# [20 rows x 35 columns]

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

lex_routes = lex_routes.drop_duplicates(subset=['source', 'dest'])
lex_routes
# Out:
#    airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6       DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 15      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
#
#       equipment  id_source  ...   country_dest iata_dest icao_dest  \
# 0           CRJ       4017  ...  United States       ATL      KATL
# 1       CR7 CRJ       4017  ...  United States       CLT      KCLT
# 2       ERD ER4       4017  ...  United States       DFW      KDFW
# 3       ERD ER4       4017  ...  United States       ORD      KORD
# 6           CRJ       4017  ...  United States       DCA      KDCA
# 7   CR7 CRJ CR9       4017  ...  United States       DTW      KDTW
# 8           ERJ       4017  ...  United States       LGA      KLGA
# 9           CRJ       4017  ...  United States       MSP      KMSP
# 10          M80       4017  ...  United States       FLL      KFLL
# 11          M80       4017  ...  United States       PGD      KPGD
# 12          320       4017  ...  United States       PIE      KPIE
# 13      M80 320       4017  ...  United States       SFB      KSFB
# 15          ERJ       4017  ...  United States       IAH      KIAH
#
#    latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0      33.636700     -84.428101           1026           -5.0         A
# 1      35.214001     -80.943100            748           -5.0         A
# 2      32.896801     -97.038002            607           -6.0         A
# 3      41.978600     -87.904800            672           -6.0         A
# 6      38.852100     -77.037697             15           -5.0         A
# 7      42.212399     -83.353401            645           -5.0         A
# 8      40.777199     -73.872597             21           -5.0         A
# 9      44.882000     -93.221802            841           -6.0         A
# 10     26.072599     -80.152702              9           -5.0         A
# 11     26.920200     -81.990501             26           -5.0         A
# 12     27.910200     -82.687401             11           -5.0         A
# 13     28.777599     -81.237503             55           -5.0         A
# 15     29.984400     -95.341400             97           -6.0         A
#
#              tz_dest type_dest
# 0   America/New_York   airport
# 1   America/New_York   airport
# 2    America/Chicago   airport
# 3    America/Chicago   airport
# 6   America/New_York   airport
# 7   America/New_York   airport
# 8   America/New_York   airport
# 9    America/Chicago   airport
# 10  America/New_York   airport
# 11  America/New_York   airport
# 12  America/New_York   airport
# 13  America/New_York   airport
# 15   America/Chicago   airport
#
# [13 rows x 35 columns]

# %%
lex_routes.to_excel("lex_routes.xlsx")

# %% [markdown]
# That looks better.  Now, let's create a map.  To avoid adding duplicate airports, we are going to use a container called a set.  A set is an unordered collection of unique elements.  This means we can keep adding LEX to the set, and end up with only 1 LEX in the end.

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2, 
                                popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_03734e41433f4ac99cbbd83c5fac8d10%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_03734e41433f4ac99cbbd83c5fac8d10%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_03734e41433f4ac99cbbd83c5fac8d10%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_03734e41433f4ac99cbbd83c5fac8d10%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# That's cool.  But airplanes don't fly in a straight line.  They follow the great circle.  So when you fly from Chicago to London, you go over Greenland (which is really pretty on a clear day!).  Can we make the lines follow a great circle?
#
# It looks like there are some options here:
#
# http://gis.stackexchange.com/questions/47/what-tools-in-python-are-available-for-doing-great-circle-distance-line-creati
#
# Let's try one of them.

# %%
import pyproj

# when creating a function, it is good practice to define the API!
def getGreatCirclePoints(startlat, startlon, endlat, endlon): 
    """
    startlat - starting latitude 
    startlon - starting longitude 
    endlat   - ending latitude 
    endlon   - ending longitude 
    
    returns - a list of tuples, where each tuple is the lat-long for a point
              along the curve.  
    """
    # calculate distance between points
    g = pyproj.Geod(ellps='WGS84')
    (az12, az21, dist) = g.inv(startlon, startlat, endlon, endlat)

    # calculate line string along path with segments <= 20 km
    lonlats = g.npts(startlon, startlat, endlon, endlat,
                     1 + int(dist / 20000))

    # the npts function uses lon-lat, while the folium functions use lat-lon
    # This sort of thing is maddening!  What happens is the lines don't show
    # up on the map and you don't know why.  Learn from my mistakes
    latlons = []
    for lon_lat in lonlats: 
        
        # this is how you get values out of a tuple
        (lon, lat) = lon_lat
        
        # add them to our list
        latlons.append((lat, lon)) 
    
    # npts doesn't include start/end points, so prepend/append them
    latlons.insert(0, (startlat, startlon))
    latlons.append((endlat, endlon))
    
    return latlons
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-235-c357b291f3f8> in <module>
# ----> 1 import pyproj
#       2
#       3 # when creating a function, it is good practice to define the API!
#       4 def getGreatCirclePoints(startlat, startlon, endlat, endlon):
#       5     """
#
# ModuleNotFoundError: No module named 'pyproj'

# %%
# any time we write a function, we should test that it works
p = getGreatCirclePoints(38.034, -84.500, 33.636700, -84.428101) 
p

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # PolyLine will accept a whole list of tuples, not just two
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']       
        
        gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
        
        line = folium.PolyLine(gc_points, weight=2, popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-237-da07f0de5f80> in <module>
#      30         popup_string = row['source'] + '-' + row['dest']
#      31
# ---> 32         gc_points = getGreatCirclePoints(row["latitude_source"],
#      33                                          row["longitude_source"],
#      34                                          row["latitude_dest"],
#
# NameError: name 'getGreatCirclePoints' is not defined

# %%
# save it to its own file
lex_air.save("lex_air.html")

# %% [markdown]
# ### Your turn
#
# The above map shows everywhere you can get to from Lexington on a direct flight.  Your job is to:
#
# 1. Make a map of all the possible destinations with one transfer.
# 2. Make a map of all the possible desitnations with two transfers.
#
# Make the maps look nice!  Use color coding, vary the size of the features, or be selective about what you display in order to communicate the information effectively.

# %%
Lex_routes= routes[routes['source']=='LEX'] # all the routes that are code share and operate in/out of Lexington 
Lex_routes
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 3588       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 5763       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5764       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 5765       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 9641       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 21095      DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 21096      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 21097      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 21098      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 21099      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 29047      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 29048      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 29049      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 29050      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 36746      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
# 57029      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
# 57030      UA      5209.0    LEX     4017.0  ORD   3830.0         Y      0
# 59544      US      5265.0    LEX     4017.0  CLT   3876.0       NaN      0
# 59545      US      5265.0    LEX     4017.0  DFW   3670.0       NaN      0
# 59546      US      5265.0    LEX     4017.0  ORD   3830.0         Y      0
#
#          equipment
# 3588           CRJ
# 5763       CR7 CRJ
# 5764       ERD ER4
# 5765       ERD ER4
# 9641       CRJ CR9
# 21095      M88 717
# 21096          CRJ
# 21097  CR7 CRJ CR9
# 21098          ERJ
# 21099          CRJ
# 29047          M80
# 29048          M80
# 29049          320
# 29050      M80 320
# 36746      CR9 CRJ
# 57029          ERJ
# 57030      ERJ CRJ
# 59544          CR7
# 59545          ERD
# 59546      ERD ER4

# %%
LEX1=pd.merge(Lex_routes,airports, left_on='source_id', right_on='id', how='left') # usually we use left join where the right table should have a set of unique ids 
LEX1
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment    id  ... iata  icao   latitude  longitude altitude  \
# 0           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 1       CR7 CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 2       ERD ER4  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 3       ERD ER4  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 4       CRJ CR9  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 5       M88 717  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 6           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 7   CR7 CRJ CR9  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 8           ERJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 9           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 10          M80  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 11          M80  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 12          320  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 13      M80 320  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 14      CR9 CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 15          ERJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 16      ERJ CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 17          CR7  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 18          ERD  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 19      ERD ER4  4017  ...  LEX  KLEX  38.036499 -84.605904      979
#
#     timezone  dst                tz     type     source_y
# 0       -5.0    A  America/New_York  airport  OurAirports
# 1       -5.0    A  America/New_York  airport  OurAirports
# 2       -5.0    A  America/New_York  airport  OurAirports
# 3       -5.0    A  America/New_York  airport  OurAirports
# 4       -5.0    A  America/New_York  airport  OurAirports
# 5       -5.0    A  America/New_York  airport  OurAirports
# 6       -5.0    A  America/New_York  airport  OurAirports
# 7       -5.0    A  America/New_York  airport  OurAirports
# 8       -5.0    A  America/New_York  airport  OurAirports
# 9       -5.0    A  America/New_York  airport  OurAirports
# 10      -5.0    A  America/New_York  airport  OurAirports
# 11      -5.0    A  America/New_York  airport  OurAirports
# 12      -5.0    A  America/New_York  airport  OurAirports
# 13      -5.0    A  America/New_York  airport  OurAirports
# 14      -5.0    A  America/New_York  airport  OurAirports
# 15      -5.0    A  America/New_York  airport  OurAirports
# 16      -5.0    A  America/New_York  airport  OurAirports
# 17      -5.0    A  America/New_York  airport  OurAirports
# 18      -5.0    A  America/New_York  airport  OurAirports
# 19      -5.0    A  America/New_York  airport  OurAirports
#
# [20 rows x 23 columns]

# %%
lex_zerostop = LEX1.drop_duplicates(subset=['source_x', 'dest',], keep='first')
lex_zerostop
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
#
#       equipment    id  ... iata  icao   latitude  longitude altitude  \
# 0           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 1       CR7 CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 2       ERD ER4  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 3       ERD ER4  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 6           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 7   CR7 CRJ CR9  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 8           ERJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 9           CRJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 10          M80  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 11          M80  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 12          320  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 13      M80 320  4017  ...  LEX  KLEX  38.036499 -84.605904      979
# 15          ERJ  4017  ...  LEX  KLEX  38.036499 -84.605904      979
#
#     timezone  dst                tz     type     source_y
# 0       -5.0    A  America/New_York  airport  OurAirports
# 1       -5.0    A  America/New_York  airport  OurAirports
# 2       -5.0    A  America/New_York  airport  OurAirports
# 3       -5.0    A  America/New_York  airport  OurAirports
# 6       -5.0    A  America/New_York  airport  OurAirports
# 7       -5.0    A  America/New_York  airport  OurAirports
# 8       -5.0    A  America/New_York  airport  OurAirports
# 9       -5.0    A  America/New_York  airport  OurAirports
# 10      -5.0    A  America/New_York  airport  OurAirports
# 11      -5.0    A  America/New_York  airport  OurAirports
# 12      -5.0    A  America/New_York  airport  OurAirports
# 13      -5.0    A  America/New_York  airport  OurAirports
# 15      -5.0    A  America/New_York  airport  OurAirports
#
# [13 rows x 23 columns]

# %%
LEX2= pd.merge(lex_zerostop, routes, left_on='dest_id', right_on='source_id',how='left',suffixes=['_source','_dest'])
LEX2
# Out:
#      airline_source  airline_id_source source_x  source_id_source dest_source  \
# 0                9E             3976.0      LEX            4017.0         ATL
# 1                9E             3976.0      LEX            4017.0         ATL
# 2                9E             3976.0      LEX            4017.0         ATL
# 3                9E             3976.0      LEX            4017.0         ATL
# 4                9E             3976.0      LEX            4017.0         ATL
# ...             ...                ...      ...               ...         ...
# 3553             UA             5209.0      LEX            4017.0         IAH
# 3554             UA             5209.0      LEX            4017.0         IAH
# 3555             UA             5209.0      LEX            4017.0         IAH
# 3556             UA             5209.0      LEX            4017.0         IAH
# 3557             UA             5209.0      LEX            4017.0         IAH
#
#       dest_id_source codeshare_source  stops_source equipment_source    id  \
# 0             3682.0              NaN             0              CRJ  4017
# 1             3682.0              NaN             0              CRJ  4017
# 2             3682.0              NaN             0              CRJ  4017
# 3             3682.0              NaN             0              CRJ  4017
# 4             3682.0              NaN             0              CRJ  4017
# ...              ...              ...           ...              ...   ...
# 3553          3550.0                Y             0              ERJ  4017
# 3554          3550.0                Y             0              ERJ  4017
# 3555          3550.0                Y             0              ERJ  4017
# 3556          3550.0                Y             0              ERJ  4017
# 3557          3550.0                Y             0              ERJ  4017
#
#       ...     source_y airline_dest airline_id_dest source source_id_dest  \
# 0     ...  OurAirports           3M         20710.0    ATL         3682.0
# 1     ...  OurAirports           3M         20710.0    ATL         3682.0
# 2     ...  OurAirports           3M         20710.0    ATL         3682.0
# 3     ...  OurAirports           3M         20710.0    ATL         3682.0
# 4     ...  OurAirports           3M         20710.0    ATL         3682.0
# ...   ...          ...          ...             ...    ...            ...
# 3553  ...  OurAirports           US          5265.0    IAH         3550.0
# 3554  ...  OurAirports           US          5265.0    IAH         3550.0
# 3555  ...  OurAirports           VA          5360.0    IAH         3550.0
# 3556  ...  OurAirports           VB         10646.0    IAH         3550.0
# 3557  ...  OurAirports           VS          5347.0    IAH         3550.0
#
#       dest_dest  dest_id_dest  codeshare_dest  stops_dest equipment_dest
# 0           LWB        6958.0             NaN           0            SF3
# 1           MCN        3754.0             NaN           0            SF3
# 2           MEI        4335.0             NaN           0            SF3
# 3           MSL        5756.0             NaN           0            SF3
# 4           PIB        5759.0             NaN           0            SF3
# ...         ...           ...             ...         ...            ...
# 3553        PHX        3462.0             NaN           0        319 320
# 3554        SAL        1892.0             NaN           0            E90
# 3555        ATL        3682.0               Y           0    M88 717 319
# 3556        MTY        1825.0             NaN           0            733
# 3557        ATL        3682.0               Y           0    M88 717 319
#
# [3558 rows x 32 columns]

# %%
lex_onestop = LEX2.drop_duplicates(subset=[ 'source','dest_dest'], keep='first')
lex_onestop
# Out:
#      airline_source  airline_id_source source_x  source_id_source dest_source  \
# 0                9E             3976.0      LEX            4017.0         ATL
# 1                9E             3976.0      LEX            4017.0         ATL
# 2                9E             3976.0      LEX            4017.0         ATL
# 3                9E             3976.0      LEX            4017.0         ATL
# 4                9E             3976.0      LEX            4017.0         ATL
# ...             ...                ...      ...               ...         ...
# 3535             UA             5209.0      LEX            4017.0         IAH
# 3536             UA             5209.0      LEX            4017.0         IAH
# 3539             UA             5209.0      LEX            4017.0         IAH
# 3542             UA             5209.0      LEX            4017.0         IAH
# 3543             UA             5209.0      LEX            4017.0         IAH
#
#       dest_id_source codeshare_source  stops_source equipment_source    id  \
# 0             3682.0              NaN             0              CRJ  4017
# 1             3682.0              NaN             0              CRJ  4017
# 2             3682.0              NaN             0              CRJ  4017
# 3             3682.0              NaN             0              CRJ  4017
# 4             3682.0              NaN             0              CRJ  4017
# ...              ...              ...           ...              ...   ...
# 3535          3550.0                Y             0              ERJ  4017
# 3536          3550.0                Y             0              ERJ  4017
# 3539          3550.0                Y             0              ERJ  4017
# 3542          3550.0                Y             0              ERJ  4017
# 3543          3550.0                Y             0              ERJ  4017
#
#       ...     source_y airline_dest airline_id_dest source source_id_dest  \
# 0     ...  OurAirports           3M         20710.0    ATL         3682.0
# 1     ...  OurAirports           3M         20710.0    ATL         3682.0
# 2     ...  OurAirports           3M         20710.0    ATL         3682.0
# 3     ...  OurAirports           3M         20710.0    ATL         3682.0
# 4     ...  OurAirports           3M         20710.0    ATL         3682.0
# ...   ...          ...          ...             ...    ...            ...
# 3535  ...  OurAirports           UA          5209.0    IAH         3550.0
# 3536  ...  OurAirports           UA          5209.0    IAH         3550.0
# 3539  ...  OurAirports           UA          5209.0    IAH         3550.0
# 3542  ...  OurAirports           UA          5209.0    IAH         3550.0
# 3543  ...  OurAirports           UA          5209.0    IAH         3550.0
#
#       dest_dest  dest_id_dest  codeshare_dest  stops_dest equipment_dest
# 0           LWB        6958.0             NaN           0            SF3
# 1           MCN        3754.0             NaN           0            SF3
# 2           MEI        4335.0             NaN           0            SF3
# 3           MSL        5756.0             NaN           0            SF3
# 4           PIB        5759.0             NaN           0            SF3
# ...         ...           ...             ...         ...            ...
# 3535        VSA        1853.0               Y           0            CR7
# 3536        XNA        4356.0               Y           0        CRJ ERJ
# 3539        YVR         156.0             NaN           0    320 319 739
# 3542        ZIH        1856.0               Y           0            ERJ
# 3543        ZLO        1858.0               Y           0            ERJ
#
# [1541 rows x 32 columns]

# %%
lex_onestop.dtypes
# Out:
# airline_source        object
# airline_id_source    float64
# source_x              object
# source_id_source     float64
# dest_source           object
# dest_id_source       float64
# codeshare_source      object
# stops_source           int64
# equipment_source      object
# id                     int64
# name                  object
# city                  object
# country               object
# iata                  object
# icao                  object
# latitude             float64
# longitude            float64
# altitude               int64
# timezone             float64
# dst                   object
# tz                    object
# type                  object
# source_y              object
# airline_dest          object
# airline_id_dest      float64
# source                object
# source_id_dest       float64
# dest_dest             object
# dest_id_dest         float64
# codeshare_dest        object
# stops_dest             int64
# equipment_dest        object
# dtype: object

# %%
lex_onestop_merged=pd.merge(lex_onestop, airports, left_on='dest_id_dest', right_on='id', how='left',suffixes=['_source','_dest'])
lex_onestop_merged
# Out:
#      airline_source  airline_id_source source_x  source_id_source dest_source  \
# 0                9E             3976.0      LEX            4017.0         ATL
# 1                9E             3976.0      LEX            4017.0         ATL
# 2                9E             3976.0      LEX            4017.0         ATL
# 3                9E             3976.0      LEX            4017.0         ATL
# 4                9E             3976.0      LEX            4017.0         ATL
# ...             ...                ...      ...               ...         ...
# 1536             UA             5209.0      LEX            4017.0         IAH
# 1537             UA             5209.0      LEX            4017.0         IAH
# 1538             UA             5209.0      LEX            4017.0         IAH
# 1539             UA             5209.0      LEX            4017.0         IAH
# 1540             UA             5209.0      LEX            4017.0         IAH
#
#       dest_id_source codeshare_source  stops_source equipment_source  \
# 0             3682.0              NaN             0              CRJ
# 1             3682.0              NaN             0              CRJ
# 2             3682.0              NaN             0              CRJ
# 3             3682.0              NaN             0              CRJ
# 4             3682.0              NaN             0              CRJ
# ...              ...              ...           ...              ...
# 1536          3550.0                Y             0              ERJ
# 1537          3550.0                Y             0              ERJ
# 1538          3550.0                Y             0              ERJ
# 1539          3550.0                Y             0              ERJ
# 1540          3550.0                Y             0              ERJ
#
#       id_source  ... iata_dest icao_dest latitude_dest longitude_dest  \
# 0          4017  ...       LWB      KLWB     37.858299     -80.399498
# 1          4017  ...       MCN      KMCN     32.692799     -83.649200
# 2          4017  ...       MEI      KMEI     32.332600     -88.751900
# 3          4017  ...       MSL      KMSL     34.745300     -87.610199
# 4          4017  ...       PIB      KPIB     31.467100     -89.337097
# ...         ...  ...       ...       ...           ...            ...
# 1536       4017  ...       VSA      MMVA     17.997000     -92.817398
# 1537       4017  ...       XNA      KXNA     36.281898     -94.306801
# 1538       4017  ...       YVR      CYVR     49.193901    -123.183998
# 1539       4017  ...       ZIH      MMZH     17.601601    -101.460999
# 1540       4017  ...       ZLO      MMZO     19.144800    -104.558998
#
#      altitude_dest  timezone_dest  dst_dest              tz_dest  type_dest  \
# 0           2302.0           -5.0         U     America/New_York    airport
# 1            354.0           -5.0         A     America/New_York    airport
# 2            297.0           -6.0         A      America/Chicago    airport
# 3            551.0           -6.0         A      America/Chicago    airport
# 4            298.0           -6.0         A      America/Chicago    airport
# ...            ...            ...       ...                  ...        ...
# 1536          46.0           -6.0         S  America/Mexico_City    airport
# 1537        1287.0           -6.0         A      America/Chicago    airport
# 1538          14.0           -8.0         A    America/Vancouver    airport
# 1539          26.0           -6.0         S  America/Mexico_City    airport
# 1540          30.0           -6.0         S  America/Mexico_City    airport
#
#       source_dest
# 0     OurAirports
# 1     OurAirports
# 2     OurAirports
# 3     OurAirports
# 4     OurAirports
# ...           ...
# 1536  OurAirports
# 1537  OurAirports
# 1538  OurAirports
# 1539  OurAirports
# 1540  OurAirports
#
# [1541 rows x 46 columns]

# %%
lex_onestop_merged.dtypes
# Out:
# airline_source        object
# airline_id_source    float64
# source_x              object
# source_id_source     float64
# dest_source           object
# dest_id_source       float64
# codeshare_source      object
# stops_source           int64
# equipment_source      object
# id_source              int64
# name_source           object
# city_source           object
# country_source        object
# iata_source           object
# icao_source           object
# latitude_source      float64
# longitude_source     float64
# altitude_source        int64
# timezone_source      float64
# dst_source            object
# tz_source             object
# type_source           object
# source_y              object
# airline_dest          object
# airline_id_dest      float64
# source_source         object
# source_id_dest       float64
# dest_dest             object
# dest_id_dest         float64
# codeshare_dest        object
# stops_dest             int64
# equipment_dest        object
# id_dest              float64
# name_dest             object
# city_dest             object
# country_dest          object
# iata_dest             object
# icao_dest             object
# latitude_dest        float64
# longitude_dest       float64
# altitude_dest        float64
# timezone_dest        float64
# dst_dest              object
# tz_dest               object
# type_dest             object
# source_dest           object
# dtype: object

# %%
lex_onestop_merged.to_excel("lex_onestop_merged_final.xlsx")

# %%
lex_onestop_merged= lex_onestop_merged.dropna()

# %%
# create a basic map, centered on Lexington
lex_air_1 = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4)

# %%
# All  the possible destinations from Lexington with one transfer.
# Define some empty sets
airport_set=set()
route_set=set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_onestop_merged.iterrows():
    
    if row['source_x'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source_x'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air_1)
        airport_set.add(row['source_x'])
        
    if row['dest_dest'] not in airport_set: 
        popup_string = row['city_source'] + '(' + row['dest_dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air_1)
        airport_set.add(row['dest_dest'])
    
   # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source_x'],row['dest_dest']) not in route_set:            
        popup_string = row['source_x'] + '-' + row['dest_dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2, 
                                popup=popup_string)
        line.add_to(lex_air_1)
        route_set.add((row['source_x'],row['dest_dest']))
        
lex_air_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e68b16a37f8447afabd10c7cd8984843%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e68b16a37f8447afabd10c7cd8984843%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e68b16a37f8447afabd10c7cd8984843%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e68b16a37f8447afabd10c7cd8984843%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# save it to its own file
lex_air_1.save("lex_air_1.html")

# %%
LEX3= pd.merge(lex_onestop, routes, left_on='dest_id_dest', right_on='source_id',how='left',suffixes=['_source','_dest'])
LEX3
# Out:
#        airline_source  airline_id_source source_x  source_id_source  \
# 0                  9E             3976.0      LEX            4017.0
# 1                  9E             3976.0      LEX            4017.0
# 2                  9E             3976.0      LEX            4017.0
# 3                  9E             3976.0      LEX            4017.0
# 4                  9E             3976.0      LEX            4017.0
# ...               ...                ...      ...               ...
# 150846             UA             5209.0      LEX            4017.0
# 150847             UA             5209.0      LEX            4017.0
# 150848             UA             5209.0      LEX            4017.0
# 150849             UA             5209.0      LEX            4017.0
# 150850             UA             5209.0      LEX            4017.0
#
#        dest_source  dest_id_source codeshare_source  stops_source  \
# 0              ATL          3682.0              NaN             0
# 1              ATL          3682.0              NaN             0
# 2              ATL          3682.0              NaN             0
# 3              ATL          3682.0              NaN             0
# 4              ATL          3682.0              NaN             0
# ...            ...             ...              ...           ...
# 150846         IAH          3550.0                Y             0
# 150847         IAH          3550.0                Y             0
# 150848         IAH          3550.0                Y             0
# 150849         IAH          3550.0                Y             0
# 150850         IAH          3550.0                Y             0
#
#        equipment_source    id  ... equipment_dest airline airline_id  \
# 0                   CRJ  4017  ...            SF3      3M    20710.0
# 1                   CRJ  4017  ...            SF3      UA     5209.0
# 2                   CRJ  4017  ...            SF3      3M    20710.0
# 3                   CRJ  4017  ...            SF3      3M    20710.0
# 4                   CRJ  4017  ...            SF3      3M    20710.0
# ...                 ...   ...  ...            ...     ...        ...
# 150846              ERJ  4017  ...            ERJ      AM      321.0
# 150847              ERJ  4017  ...            ERJ      AS      439.0
# 150848              ERJ  4017  ...            ERJ      UA     5209.0
# 150849              ERJ  4017  ...            ERJ      VW     1290.0
# 150850              ERJ  4017  ...            ERJ      Y4     5325.0
#
#        source_dest source_id  dest  dest_id  codeshare  stops equipment
# 0              LWB    6958.0   ATL   3682.0        NaN    0.0       SF3
# 1              LWB    6958.0   IAD   3714.0          Y    0.0       SF3
# 2              MCN    3754.0   ATL   3682.0        NaN    0.0       SF3
# 3              MCN    3754.0   MCO   3878.0        NaN    0.0       SF3
# 4              MEI    4335.0   ATL   3682.0        NaN    0.0       SF3
# ...            ...       ...   ...      ...        ...    ...       ...
# 150846         ZLO    1858.0   MEX   1824.0          Y    0.0   E75 ERJ
# 150847         ZLO    1858.0   LAX   3484.0        NaN    0.0       73H
# 150848         ZLO    1858.0   IAH   3550.0          Y    0.0       ERJ
# 150849         ZLO    1858.0   MEX   1824.0        NaN    0.0       ATR
# 150850         ZLO    1858.0   TIJ   1847.0        NaN    0.0       319
#
# [150851 rows x 41 columns]

# %%
lex_twostop = LEX3.drop_duplicates(subset=['source_dest', 'dest'], keep='first')
lex_twostop
# Out:
#        airline_source  airline_id_source source_x  source_id_source  \
# 0                  9E             3976.0      LEX            4017.0
# 1                  9E             3976.0      LEX            4017.0
# 2                  9E             3976.0      LEX            4017.0
# 3                  9E             3976.0      LEX            4017.0
# 4                  9E             3976.0      LEX            4017.0
# ...               ...                ...      ...               ...
# 150841             UA             5209.0      LEX            4017.0
# 150844             UA             5209.0      LEX            4017.0
# 150845             UA             5209.0      LEX            4017.0
# 150848             UA             5209.0      LEX            4017.0
# 150850             UA             5209.0      LEX            4017.0
#
#        dest_source  dest_id_source codeshare_source  stops_source  \
# 0              ATL          3682.0              NaN             0
# 1              ATL          3682.0              NaN             0
# 2              ATL          3682.0              NaN             0
# 3              ATL          3682.0              NaN             0
# 4              ATL          3682.0              NaN             0
# ...            ...             ...              ...           ...
# 150841         IAH          3550.0                Y             0
# 150844         IAH          3550.0                Y             0
# 150845         IAH          3550.0                Y             0
# 150848         IAH          3550.0                Y             0
# 150850         IAH          3550.0                Y             0
#
#        equipment_source    id  ... equipment_dest airline airline_id  \
# 0                   CRJ  4017  ...            SF3      3M    20710.0
# 1                   CRJ  4017  ...            SF3      UA     5209.0
# 2                   CRJ  4017  ...            SF3      3M    20710.0
# 3                   CRJ  4017  ...            SF3      3M    20710.0
# 4                   CRJ  4017  ...            SF3      3M    20710.0
# ...                 ...   ...  ...            ...     ...        ...
# 150841              ERJ  4017  ...            ERJ      UA     5209.0
# 150844              ERJ  4017  ...            ERJ      4O    17885.0
# 150845              ERJ  4017  ...            ERJ      AM      321.0
# 150848              ERJ  4017  ...            ERJ      UA     5209.0
# 150850              ERJ  4017  ...            ERJ      Y4     5325.0
#
#        source_dest source_id  dest  dest_id  codeshare  stops equipment
# 0              LWB    6958.0   ATL   3682.0        NaN    0.0       SF3
# 1              LWB    6958.0   IAD   3714.0          Y    0.0       SF3
# 2              MCN    3754.0   ATL   3682.0        NaN    0.0       SF3
# 3              MCN    3754.0   MCO   3878.0        NaN    0.0       SF3
# 4              MEI    4335.0   ATL   3682.0        NaN    0.0       SF3
# ...            ...       ...   ...      ...        ...    ...       ...
# 150841         ZIH    1856.0   IAH   3550.0          Y    0.0       ERJ
# 150844         ZLO    1858.0   MEX   1824.0        NaN    0.0       SU9
# 150845         ZLO    1858.0   LAX   3484.0          Y    0.0       73H
# 150848         ZLO    1858.0   IAH   3550.0          Y    0.0       ERJ
# 150850         ZLO    1858.0   TIJ   1847.0        NaN    0.0       319
#
# [12760 rows x 41 columns]

# %%
lex_twostop_merged=pd.merge(lex_twostop, airports, left_on='dest_id', right_on='id', how='left',suffixes=['_source','_dest2'])
lex_twostop_merged
# Out:
#       airline_source  airline_id_source source_x  source_id_source  \
# 0                 9E             3976.0      LEX            4017.0
# 1                 9E             3976.0      LEX            4017.0
# 2                 9E             3976.0      LEX            4017.0
# 3                 9E             3976.0      LEX            4017.0
# 4                 9E             3976.0      LEX            4017.0
# ...              ...                ...      ...               ...
# 12755             UA             5209.0      LEX            4017.0
# 12756             UA             5209.0      LEX            4017.0
# 12757             UA             5209.0      LEX            4017.0
# 12758             UA             5209.0      LEX            4017.0
# 12759             UA             5209.0      LEX            4017.0
#
#       dest_source  dest_id_source codeshare_source  stops_source  \
# 0             ATL          3682.0              NaN             0
# 1             ATL          3682.0              NaN             0
# 2             ATL          3682.0              NaN             0
# 3             ATL          3682.0              NaN             0
# 4             ATL          3682.0              NaN             0
# ...           ...             ...              ...           ...
# 12755         IAH          3550.0                Y             0
# 12756         IAH          3550.0                Y             0
# 12757         IAH          3550.0                Y             0
# 12758         IAH          3550.0                Y             0
# 12759         IAH          3550.0                Y             0
#
#       equipment_source  id_source  ... iata_dest2 icao_dest2 latitude_dest2  \
# 0                  CRJ       4017  ...        ATL       KATL      33.636700
# 1                  CRJ       4017  ...        IAD       KIAD      38.944500
# 2                  CRJ       4017  ...        ATL       KATL      33.636700
# 3                  CRJ       4017  ...        MCO       KMCO      28.429399
# 4                  CRJ       4017  ...        ATL       KATL      33.636700
# ...                ...        ...  ...        ...        ...            ...
# 12755              ERJ       4017  ...        IAH       KIAH      29.984400
# 12756              ERJ       4017  ...        MEX       MMMX      19.436300
# 12757              ERJ       4017  ...        LAX       KLAX      33.942501
# 12758              ERJ       4017  ...        IAH       KIAH      29.984400
# 12759              ERJ       4017  ...        TIJ       MMTJ      32.541100
#
#       longitude_dest2 altitude_dest2  timezone_dest2  dst_dest2  \
# 0          -84.428101         1026.0            -5.0          A
# 1          -77.455803          312.0            -5.0          A
# 2          -84.428101         1026.0            -5.0          A
# 3          -81.308998           96.0            -5.0          A
# 4          -84.428101         1026.0            -5.0          A
# ...               ...            ...             ...        ...
# 12755      -95.341400           97.0            -6.0          A
# 12756      -99.072098         7316.0            -6.0          S
# 12757     -118.407997          125.0            -8.0          A
# 12758      -95.341400           97.0            -6.0          A
# 12759     -116.970001          489.0            -8.0          S
#
#                   tz_dest2  type_dest2       source
# 0         America/New_York     airport  OurAirports
# 1         America/New_York     airport  OurAirports
# 2         America/New_York     airport  OurAirports
# 3         America/New_York     airport  OurAirports
# 4         America/New_York     airport  OurAirports
# ...                    ...         ...          ...
# 12755      America/Chicago     airport  OurAirports
# 12756  America/Mexico_City     airport  OurAirports
# 12757  America/Los_Angeles     airport  OurAirports
# 12758      America/Chicago     airport  OurAirports
# 12759      America/Tijuana     airport  OurAirports
#
# [12760 rows x 55 columns]

# %%
lex_twostop_merged.dtypes
# Out:
# airline_source        object
# airline_id_source    float64
# source_x              object
# source_id_source     float64
# dest_source           object
# dest_id_source       float64
# codeshare_source      object
# stops_source           int64
# equipment_source      object
# id_source              int64
# name_source           object
# city_source           object
# country_source        object
# iata_source           object
# icao_source           object
# latitude_source      float64
# longitude_source     float64
# altitude_source        int64
# timezone_source      float64
# dst_source            object
# tz_source             object
# type_source           object
# source_y              object
# airline_dest          object
# airline_id_dest      float64
# source_source         object
# source_id_dest       float64
# dest_dest             object
# dest_id_dest         float64
# codeshare_dest        object
# stops_dest             int64
# equipment_dest        object
# airline               object
# airline_id           float64
# source_dest           object
# source_id            float64
# dest                  object
# dest_id              float64
# codeshare             object
# stops                float64
# equipment             object
# id_dest2             float64
# name_dest2            object
# city_dest2            object
# country_dest2         object
# iata_dest2            object
# icao_dest2            object
# latitude_dest2       float64
# longitude_dest2      float64
# altitude_dest2       float64
# timezone_dest2       float64
# dst_dest2             object
# tz_dest2              object
# type_dest2            object
# source                object
# dtype: object

# %%
lex_twostop_merged.to_excel("lex_twostop_merged_final.xlsx")

# %%
lex_twostop_merged=lex_twostop_merged.dropna()

# %%
# create a basic map, centered on Lexington
lex_air_2 = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4)

# %%
# All  the possible destinations from Lexington with one transfer.
# Define some empty sets
airport_set= set()
route_set= set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_twostop_merged.iterrows():
    
    if row['source_x'] not in airport_set: 
        popup_string = row['city_source'] + '(' + row['source_x'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air_2)
        airport_set.add(row['source_x'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest2'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest2"], row["longitude_dest2"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air_2)
        airport_set.add(row['dest'])
    
   # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source_x'],row['dest']) not in route_set:            
        popup_string = row['source_x'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest2"],row["longitude_dest2"])], 
                                weight=2, 
                                popup=popup_string)
        line.add_to(lex_air_2)
        route_set.add((row['source_x'],row['dest']))
        
lex_air_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ab4376d3783c4c50a0c0b34d00ce4688%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ab4376d3783c4c50a0c0b34d00ce4688%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ab4376d3783c4c50a0c0b34d00ce4688%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ab4376d3783c4c50a0c0b34d00ce4688%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
lex_air_2.save("lex_air_2.html")
